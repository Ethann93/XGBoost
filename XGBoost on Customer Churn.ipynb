# %% [markdown]
# # XGBoost on Telco Customer Churn

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from sklearn import metrics
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, \
f1_score, confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, \
StackingRegressor, VotingRegressor, RandomForestClassifier
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.svm import SVR

from xgboost import XGBClassifier, plot_importance

import pickle

# %%
df = pd.read_csv('Telco_customer_churn.csv')

# %% [markdown]
# ## Data Exploration & Cleaning

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value  Churn Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %% [markdown]
# ### Drop Unnecessary Columns

# %%
df.drop(['Churn Label', 'Churn Score', 'CLTV', 'Churn Reason'],
       axis = 1, inplace=True)
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
df['Count'].unique()
# Out:
# array([1], dtype=int64)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['State'].unique()
# Out:
# array(['California'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Los Angeles', 'Beverly Hills', 'Huntington Park', ..., 'Standish',
#        'Tulelake', 'Olympic Valley'], dtype=object)

# %% [markdown]
# we wil drop the follwoing columns since they have only 1 value in them:
#  - Count
#  - Country
#  - State
#
# We will also drop 'Lat Long' since there are seperate columns for Latitude and Longitude.
#
# we will also drop CustomerID since it wont be useful in our XGBoost analysis.

# %%
df.drop(['Count', 'Country', 'State', 'Lat Long', 'CustomerID'],
       axis = 1, inplace=True)
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
df['Churn Value'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn Value, dtype: int64

# %% [markdown]
# ### Remove White Spaces in The Data

# %% [markdown]
# #### Replace Blank Space with UnderScore in The 'City' Column

# %%
df['City'].replace(' ','_', regex = True, inplace= True)
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
df['City'].unique()
# Out:
# array(['Los_Angeles', 'Beverly_Hills', 'Huntington_Park', ..., 'Standish',
#        'Tulelake', 'Olympic_Valley'], dtype=object)

# %% [markdown]
# #### Replace Blank Space with UnderScore in The Column Names

# %%
df.columns = df.columns.str.replace(' ', '_')
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# ### Check for Missing and Duplicated Data

# %% [markdown]
# #### Check for NaN Values

# %%
df.isna().sum()
# Out:
# City                 0
# Zip_Code             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior_Citizen       0
# Partner              0
# Dependents           0
# Tenure_Months        0
# Phone_Service        0
# Multiple_Lines       0
# Internet_Service     0
# Online_Security      0
# Online_Backup        0
# Device_Protection    0
# Tech_Support         0
# Streaming_TV         0
# Streaming_Movies     0
# Contract             0
# Paperless_Billing    0
# Payment_Method       0
# Monthly_Charges      0
# Total_Charges        0
# Churn_Value          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %% [markdown]
# #### Change Total_charges Type to Numeric

# %%
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-273-eda391cc01c5> in <module>
# ----> 1 df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
#     185                 values, set(), coerce_numeric=coerce_numeric
#     186             )
#
# ...

# %% [markdown]
# 'Total_Charges' has blank spaces that can't be changed to numeric.

# %% [markdown]
# ##### Replace the Missing Data in 'Total_Charges' to 0

# %%
# Number of rows with missing values
len(df.loc[df['Total_Charges'] == ' '])
# Out:
# 11

# %%
df.loc[df['Total_Charges'] == ' ']
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %% [markdown]
# The reason the **'Total_Charges'** column is blank is because the **'Churn_Value'** is 0 identifying that the custmer were not charged for anything.

# %%
df.loc[(df['Total_Charges'] == ' '), 'Total_Charges'] = 0

# %%
df.loc[df['Total_Charges'] == ' ']
# Out:
# Empty DataFrame
# Columns: [City, Zip_Code, Latitude, Longitude, Gender, Senior_Citizen, Partner, Dependents, Tenure_Months, Phone_Service, Multiple_Lines, Internet_Service, Online_Security, Online_Backup, Device_Protection, Tech_Support, Streaming_TV, Streaming_Movies, Contract, Paperless_Billing, Payment_Method, Monthly_Charges, Total_Charges, Churn_Value]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])

# %% [markdown]
# #### Replace Blank Space with UnderScore in All Columns Of the DataFrame

# %%
df.replace(' ','_', regex =True, inplace=True)
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %%
df['Churn_Value'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn_Value, dtype: int64

# %% [markdown]
# ## XGBoost Modelling

# %% [markdown]
# ### Split the Data Into Variables Features (X) and Traget Variables (Y)

# %%
X = df.drop('Churn_Value', axis=1).copy()

# %%
X.isnull().sum()
# Out:
# City                 0
# Zip_Code             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior_Citizen       0
# Partner              0
# Dependents           0
# Tenure_Months        0
# Phone_Service        0
# Multiple_Lines       0
# Internet_Service     0
# Online_Security      0
# Online_Backup        0
# Device_Protection    0
# Tech_Support         0
# Streaming_TV         0
# Streaming_Movies     0
# Contract             0
# Paperless_Billing    0
# Payment_Method       0
# Monthly_Charges      0
# Total_Charges        0
# dtype: int64

# %%
y = df['Churn_Value'].copy()

# %%
y.isnull().sum()
# Out:
# 0

# %%
X.shape
# Out:
# (7043, 23)

# %%
y.shape
# Out:
# (7043,)

# %% [markdown]
# ### One-Hot Encoding

# %%
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %% [markdown]
# #### Change The Categorical Columns Into Binary Numbers

# %%
X_encoded = pd.get_dummies(X, columns=['City',
                          'Gender',
                          'Senior_Citizen',
                          'Partner',
                          'Dependents',
                          'Phone_Service',
                          'Multiple_Lines',
                          'Internet_Service',
                          'Online_Security',
                          'Online_Backup',
                          'Device_Protection',
                          'Tech_Support',
                          'Streaming_TV',
                          'Streaming_Movies',
                          'Contract',
                          'Paperless_Billing',
                          'Payment_Method'])
X_encoded.head()
# Out:
#    Zip_Code   Latitude   Longitude  Tenure_Months  Monthly_Charges  \
# 0     90003  33.964131 -118.272783              2            53.85
# 1     90005  34.059281 -118.307420              2            70.70
# 2     90006  34.048013 -118.293953              8            99.65
# 3     90010  34.062125 -118.315709             28           104.80
# 4     90015  34.039224 -118.266293             49           103.70
#
#    Total_Charges  City_Acampo  City_Acton  City_Adelanto  City_Adin  ...  \
# 0         108.15            0           0              0          0  ...
# 1         151.65            0           0              0          0  ...
# 2         820.50            0           0              0          0  ...
# 3        3046.05            0           0              0          0  ...
# 4        5036.30            0           0              0          0  ...
#
#    Streaming_Movies_Yes  Contract_Month-to-month  Contract_One_year  \
# ...

# %%
y.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
X_encoded.shape
# Out:
# (7043, 1178)

# %% [markdown]
# ### Building The Model

# %% [markdown]
# #### Check The Balance Of The DataSet

# %%
sum(y)/len(y)
# Out:
# 0.2653698707936959

# %% [markdown]
# Approximately 27% of people have left the company. Therefore, we will splitthe data using stratification in order to maintain the same percentage of people who left the company for both the training and testing set.

# %% [markdown]
# #### Split the Data Into Training & Test Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state = 42, stratify = y)

# %%
X_train.shape
# Out:
# (5282, 1178)

# %%
X_test.shape
# Out:
# (1761, 1178)

# %%
y_test.shape
# Out:
# (1761,)

# %%
y_train.shape
# Out:
# (5282,)

# %% [markdown]
# #### Check If Stratifying Has Worked

# %%
sum(y_train) / len(y_train)
# Out:
# 0.2654297614539947

# %%
sum(y_test) / len(y_test)
# Out:
# 0.26519023282226006

# %%
xgb = XGBClassifier(objective='binary:logistic', random_state=0)
cv_params = {'max_depth': [4,5,6,7,8],
'min_child_weight': [1,2,3,4,5],
'learning_rate': [0.1, 0.2, 0.3],
'n_estimators': [75, 100, 125]
}
scoring = {'accuracy', 'precision', 'recall', 'f1'}
xgb_cv = GridSearchCV(xgb, cv_params, scoring=scoring, cv=5, refit='f1')

# %%
# %%time
xgb_cv.fit(X_train, y_train)
# Out:
# Wall time: 1h 21min 21s
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
# %%time
# Define and train the Random Forest model
clf_rf = RandomForestClassifier(n_estimators=100, random_state=42)
f1_scores_rf = cross_val_score(clf_rf, X_encoded, y, cv=5, scoring='f1')

# Define and train the XGBoost model
clf_xgb = XGBClassifier(objective='binary:logistic', learning_rate=0.1, max_depth=3, n_estimators=100, missing=-999, seed=42)
f1_scores_xgb = cross_val_score(clf_xgb, X_encoded, y, cv=5, scoring='f1')
# Out:
# Wall time: 32 s

# %%
# Fit the XGBoost model explicitly
clf_xgb.fit(X_encoded, y)

print('F1 score Random Forest CV: ', f1_scores_rf.mean())
print('F1 score XGBoost CV: ', f1_scores_xgb.mean())
# Out:
# F1 score Random Forest CV:  0.5541409000873536
# F1 score XGBoost CV:  0.6028133787698323

# %%
def make_results(model_name, model_object):
    '''
    Accepts as arguments a model name (your choice - string) and
    a fit GridSearchCV model object.
    Returns a pandas df with the F1, recall, precision, and accuracy scores
    for the model with the best mean F1 score across all validation folds.
    '''
    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)
    
    # Isolate the row of the df with the max(mean f1 score)
    best_estimator_results = cv_results.iloc[cv_results['mean_test_f1'],idxmax(), :]
    
    # Extract accuracy, precision, recall, and f1 score from that row
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy
    
    # Create table of results
    table = pd.DataFrame()
    table = table.append({'Model': model_name,'F1': f1,
    'Recall': recall,
    'Precision': precision,
    'Accuracy': accuracy
    },
    ignore_index=True
    )
    return table

# %%
# Predict on test data
clf_xgb_preds = clf_xgb.predict(X_test)
print('F1 score final XGB model: ', f1_score(y_test, clf_xgb_preds))
print('Recall score final XGB model: ', recall_score(y_test, clf_xgb_preds))
print('Precision score final XGB model: ', precision_score(y_test, clf_xgb_preds))
print('Accuracy score final XGB model: ', accuracy_score(y_test, clf_xgb_preds))
# Out:
# F1 score final XGB model:  0.6266195524146053
# Recall score final XGB model:  0.569593147751606
# Precision score final XGB model:  0.6963350785340314
# Accuracy score final XGB model:  0.8199886428165815

# %% [markdown]
# ## Confusion Matrix

# %%
def conf_matrix_plot(model, x_data, y_data, display_labels=['Did not leave', 'Left']):
    """
    Plot a confusion matrix for the specified model.

    Parameters:
    - model: Fitted model with a predict method (e.g., XGBoost classifier)
    - x_data: Features for prediction
    - y_data: True labels
    - display_labels: List of class labels for display (default: ['Did not leave', 'Left'])
    """
    # Predict on the given data
    y_pred = model.predict(x_data)

    # Calculate confusion matrix
    cm = confusion_matrix(y_data, y_pred, labels=model.classes_)

    # Display the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
    disp.plot(values_format='d')

    # Show the plot
    plt.show()

# %%
 conf_matrix_plot(xgb_cv.best_estimator_, X_test, y_test, display_labels=['Did not leave', 'Left']);

# %% [markdown]
# From the 1761 people in our test data, there are 598 customers who left the bank. Of those, our
# model captures 377. The confusion matrix indicates that, when the model makes an error, it’s
# usually a **Type II error**—it gives a false negative by failing to predict that a customer will leave.
# On the other hand, it makes far fewer **Type I errors**, which are false positives.

# %% [markdown]
# ## Feature Importance

# %%
# Specify the figure size (change width and height as needed)
fig, ax = plt.subplots(figsize=(16, 20))

# Assuming xgb_cv.best_estimator_ is your fitted XGBoost model
plot_importance(xgb_cv.best_estimator_, ax=ax)

plt.show()

# %% [markdown]
# This tells us that the four most important features used by our model were **Monthly Charges**,
# **Total Charges** and **Tenure Months**. This is very useful information.
